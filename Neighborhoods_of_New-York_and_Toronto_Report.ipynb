# %% [markdown]
# <h1 align=center><font size = 5>Capstone Project - Report</font></h1>
# <h1 align=center><font size = 5>Analyzing the Neighborhoods of New-York City and Toronto</font></h1>
# <h1 align=center><font size = 3>Applied Data Science Capstone by IBM/Coursera</font></h1>

# %% [markdown]
# ### VIJAYAKUMAR R HIRAPURE
# ### July 31, 2021

# %% [markdown]
# ## Table of contents
# * [Introduction](#introduction)
# * [Data Description](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# ## Introduction

# %% [markdown]
# ### Background

# %% [markdown]
# New York or NYC for short, is the most populous city in the United States. New York City is also the most densely populated major city in the United States. New York City has been described as the cultural, financial, and media capital of the world, significantly influencing commerce,entertainment, research, technology, education, politics, tourism, art, fashion, and sports.
#
# Toronto is the capital city of the Canadian province of Ontario. it is the most populous city in Canada and the fourth most populous city in North America. Toronto is an international centre of business, finance, arts, and culture, and is recognized as one of the most multicultural and cosmopolitan cities in the world.
#
# We try to group the neighbourhoods of New-York City and Toronto respectively and draw insights to determine how similar or dissimilar they are.

# %% [markdown]
# ### Business Problem

# %% [markdown]
# The aim is to help tourists choose their destinations depending on the experiences that the neighbourhoods have to offer and what they would want to have. This also helps people make decisions if they are thinking about migrating to New York City or Toronto or even if they want to relocate neighbourhoods within the city. Our findings will help stakeholders make informed decisions and address any concerns they have including the different kinds of cuisines, provision stores and what the city has to offer.

# %% [markdown]
# ### Target Audience / Stakeholders

# %% [markdown]
# Help tourists to choose their destinations/Venues.
# Helps Business personnel to know which are the best places to invest or to do business.
# Helps people make decisions if they are thinking about migrating/relocating neighbourhoods within the city.
# Helps stakeholders make informed decisions and address any concerns they have including the different kinds of cuisines, provision stores and what the city has to offer.

# %% [markdown]
# ## Data Description

# %% [markdown]
# We require geolocation data for both New York City and Toronto.We use Geographical Location data using Geocoder Package Data Source: https://cocl.us/Geospatial_data
#
# This project aims to leverage venue data from Foursquare’s ‘Places API’Venue Data using Foursquare API Data Source: https://foursquare.com/developers/apps
#
# Machine learning algorithm called ‘k-means clustering’ to identify ‘New York City’ and Toronto neighborhoods.

# %% [markdown]
# ### New York City

# %% [markdown]
# #### Data Source and Description

# %% [markdown]
# The "New York City Neighborhood Names" dataset hosted by NYU’s Spatial Data Repository forms as the basis for the neighborhood names and associated location centroids.
#
# To derive our solution, we leverage same json data available at "Skills Network Lab" , https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/labs/newyork_data.json.
#
# The dataset available was easy to download as a JSON file and import into a Jupyter Notebook: This datset has information about Borough, Neighbourhoods, Latitude, Longitude etc.
#
# The ‘Borough’, ‘Neighborhood’, ‘Latitude’, and ‘Longitude’ values associated with each neighborhood were then converted from JSON to a Pandas DataFrame that serves as the foundation of the analysis.

# %% [markdown]
# ### Toronto

# %% [markdown]
# #### Data Source and Description

# %% [markdown]
# Postal codes of Canada available at wikipedia page serve as a starting point. Using Postal codes we can find out the neighbourhoods, boroughs, venues and their most popular venue categories.
#
# To derive our solution, we scrape our data from wikipedia https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M. This wikipedia page has information about all the neighbourhoods, we limit it to Toronto.
#
# This datset has information about Postal Code,Borough, Neighbourhoods etc.
#
# Using BeautifulSoup the data is preprocessed and then converted to a Pandas Dataframe that serves as the foundation of the analysis.

# %% [markdown]
# ### Foursquare API Data

# %% [markdown]
# We will need data about different venues in different neighbourhoods of that specific borough. In order to gain that information we will use "Foursquare" locational information. Foursquare is a location data provider with information about venues and events within an area of interest. Such information includes venue names, locations, menus and even photos. As such, the foursquare location platform will be used as the sole data source since all the stated required information can be obtained through the API.
#
# The data retrieved from Foursquare contained information of venues within a specified distance of the longitude and latitude of the postcodes. The information obtained per venue are as follows:
#
# Neighbourhood : Name of the Neighbourhood
# Neighbourhood Latitude : Latitude of the Neighbourhood
# Neighbourhood Longitude : Longitude of the Neighbourhood
# Venue : Name of the Venue
# Venue Latitude : Latitude of Venue
# Venue Longitude : Longitude of Venue
# Venue Category : Category of Venue
#
# Based on the information collected for both New York City and Toronto, we have sufficient data to build our model. We cluster the neighbourhoods together based on similar venue categories. We then present our observations and findings. Using this data, our stakeholders can take the necessary decision.

# %% [markdown]
# ### TechStack/framework Used

# %% [markdown]
# Machine Learning Algorithm
# Web Scraping
# Foursquare API
# Geocoder
# Python / Pandas Dataframe
# Beautiful Soup
# Folium

# %% [markdown]
# ## Methodology

# %% [markdown]
# In this project we will direct our efforts on detecting neighbourhoods of New York City and Toronto that helps people to choose their destination depending on the experiences that the neighbourhoods have to offer and what they would want to have, particularly helps people make decisions if they are thinking about migrating to New York City or Toronto or even if they want to relocate neighbourhoods within the city.We will also direct our efforts on detecting neighbourhoods of New York City and Toronto that helps people to do business, i.e. either for opening up a new restaurant etc.
#
# In the first step we are going to collect the required data: borough, neighbourhood location and latitude, longitude information. We are also going to identify 100 venue locations that are within a radius of 500 meters..
#
# Second step in our analysis will be exploration of neighbourhoods.We are going to use "Folium" visualization library to create a map of New York with neighborhoods superimposed on top of it. Then we are going to find venues across neighbourhoods and also identify 10 most common venues in each neighbourhood of New York city and Toronto.Then we focus our attention on those neighbourhoods.
#
# In third and final step we will focus on top neighbourhoods and then create clusters of neighbourhoods. The clustering of neighbourhoods is done by means of using k-means machine learning algorithm. We will present map of all such neighbourhoods by using "Folium" visualization library. We then identify clusters with most and least number of neighbourhoods.

# %% [markdown]
# ## Analysis <a name="analysis"></a>

# %% [markdown]
# ### Prerequisite

# %% [markdown]
# The following packages are required for the implementation of the project

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
#import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ### New York city

# %% [markdown]
# #### Data Collection

# %%
# !wget -q -O 'newyork_data.json' https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/labs/newyork_data.json
print('Data downloaded!')
# Out:
# Data downloaded!

# %%
with open('newyork_data.json') as json_data:
    newyork_data = json.load(json_data)

# %%
# Features Selection
ny_neighborhoods_data = newyork_data['features']

# %% [markdown]
# #### Preprocessing

# %% [markdown]
# **Tranform the data into a pandas dataframe**

# %%
# define the dataframe columns
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
NewYork_neighborhoods = pd.DataFrame(columns=column_names)

# %% [markdown]
# Then let's loop through the data and fill the dataframe one row at a time.

# %%
for data in ny_neighborhoods_data:
    borough = neighborhood_name = data['properties']['borough'] 
    neighborhood_name = data['properties']['name']
        
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    NewYork_neighborhoods = NewYork_neighborhoods.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)

# %% [markdown]
# Afer data downloading, preprocessing and cleaning we have the resulting dataframe.

# %%
NewYork_neighborhoods.head()
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %%
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(NewYork_neighborhoods['Borough'].unique()),
        NewYork_neighborhoods.shape[0]
    )
)
# Out:
# The dataframe has 5 boroughs and 306 neighborhoods.

# %% [markdown]
# ### Toronto

# %% [markdown]
# #### Data Collection

# %% [markdown]
# To get the neighbourhoods in Toronto, we start by scraping and cleaning the list of areas of Canada wiki page.

# %%
from bs4 import BeautifulSoup
source = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M").text
soup = BeautifulSoup(source, 'lxml')

table = soup.find("table")
row = table.tbody.find_all("tr")

table_contents = []

for row in table.findAll('td'):
    cell = {}
    if row.span.text=='Not assigned':
        pass
    else:
        cell['PostalCode'] = row.p.text[:3]
        cell['Borough'] = (row.span.text).split('(')[0]
        cell['Neighborhood'] = (((((row.span.text).split('(')[1]).strip(')')).replace(' /',',')).replace(')',' ')).strip(' ')
        table_contents.append(cell)

# print(table_contents)
df=pd.DataFrame(table_contents)

# %% [markdown]
# #### Preprocessing

# %%
# Dropping the rows where Borough is 'Not assigned'
# 'Not assigned' condition is already taken care in the above code,doesn't affect here
df1 = df[df.Borough != 'Not assigned']

# Combining the neighbourhoods with same Postalcode
df2 = df1.groupby(['PostalCode','Borough'], sort=False).agg(', '.join)
df2.reset_index(inplace=True)

# Replacing the name of the neighbourhoods which are 'Not assigned' with names of Borough
df2['Neighborhood'] = np.where(df2['Neighborhood'] == 'Not assigned',df2['Borough'], df2['Neighborhood'])

# Replacing the longer name of the Borough with the shorter names
df2['Borough']=df2['Borough'].replace({'Downtown TorontoStn A PO Boxes25 The Esplanade':'Downtown Toronto Stn A',
                                             'East TorontoBusiness reply mail Processing Centre969 Eastern':'East Toronto Business',
                                             'EtobicokeNorthwest':'Etobicoke Northwest','East YorkEast Toronto':'East York/East Toronto',
                                             'MississaugaCanada Post Gateway Processing Centre':'Mississauga'})


# The dataframe will consist of three columns: PostalCode, Borough, and Neighborhood
df2.head()
# Out:
#   PostalCode           Borough                      Neighborhood
# 0        M3A        North York                         Parkwoods
# 1        M4A        North York                  Victoria Village
# 2        M5A  Downtown Toronto         Regent Park, Harbourfront
# 3        M6A        North York  Lawrence Manor, Lawrence Heights
# 4        M7A      Queen's Park     Ontario Provincial Government

# %% [markdown]
# #### Importing the csv file conatining the latitudes and longitudes for various neighbourhoods in Canada

# %%
lat_lon = pd.read_csv('https://cocl.us/Geospatial_data')
lat_lon.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# Merging the two tables for getting the Latitudes and Longitudes for various neighbourhoods in Canada

# %%
df2.rename(columns={'PostalCode':'Postal Code'},inplace=True)
df_toronto = pd.merge(df2,lat_lon,on='Postal Code')
df_toronto.head()
# Out:
#   Postal Code           Borough                      Neighborhood   Latitude  \
# 0         M3A        North York                         Parkwoods  43.753259
# 1         M4A        North York                  Victoria Village  43.725882
# 2         M5A  Downtown Toronto         Regent Park, Harbourfront  43.654260
# 3         M6A        North York  Lawrence Manor, Lawrence Heights  43.718518
# 4         M7A      Queen's Park     Ontario Provincial Government  43.662301
#
#    Longitude
# 0 -79.329656
# 1 -79.315572
# 2 -79.360636
# 3 -79.464763
# 4 -79.389494

# %% [markdown]
# Afer data downloading, preprocessing and cleaning we have the resulting dataframe for Toronto.

# %%
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(df_toronto['Borough'].unique()),
        df_toronto.shape[0]
    )
)
# Out:
# The dataframe has 15 boroughs and 103 neighborhoods.

# %% [markdown]
# ### Visualizing the Neighbourhoods of New-York city and Toronto

# %% [markdown]
# #### Use geopy library to get the latitude and longitude values of New York City.

# %%
address = 'New York City, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of New York City are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of New York City are 40.7127281, -74.0060152.

# %% [markdown]
# **Getting the latitude and longitude values of Toronto**

# %%
address = "Toronto, ON"

geolocator = Nominatim(user_agent="toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto city are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto city are 43.6534817, -79.3839347.

# %% [markdown]
# #### Define Foursquare Credentials and Version

# %%
# The code was removed by Watson Studio for sharing.

# %% [markdown]
# #### Creating a map of New York city with neighborhoods superimposed on top using folium library.

# %%
# create map of New York using latitude and longitude values
map_newyork = folium.Map(location=[latitude, longitude], zoom_start=10)
map_newyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %% [markdown]
# #### Creating a map of Toronto with neighborhoods superimposed on top using folium library.

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %% [markdown]
# Dataframe with neighborhoods which contains Toronto word in their Borough name.

# %%
# "denc" = [D]owntown Toronto, [E]ast Toronto, [N]orth Toronto, [C]entral Toronto
df_toronto_denc = df_toronto[df_toronto['Borough'].str.contains("Toronto")].reset_index(drop=True)
df_toronto_denc.head()
# Out:
#   Postal Code           Borough               Neighborhood   Latitude  \
# 0         M5A  Downtown Toronto  Regent Park, Harbourfront  43.654260
# 1         M5B  Downtown Toronto   Garden District, Ryerson  43.657162
# 2         M5C  Downtown Toronto             St. James Town  43.651494
# 3         M4E      East Toronto                The Beaches  43.676357
# 4         M5E  Downtown Toronto                Berczy Park  43.644771
#
#    Longitude
# 0 -79.360636
# 1 -79.378937
# 2 -79.375418
# 3 -79.293031
# 4 -79.373306

# %%
Creating a map of Toronto with neighborhoods which contains Toronto word in their Borough name using folium library.

# %%
map_toronto_denc = folium.Map(location=[latitude, longitude], zoom_start=12)
map_toronto_denc
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %% [markdown]
# #### New York city : Let's get the top 100 venues that are within a radius of 500 meters

# %%
ny_venues = getNearbyVenues(names=NewYork_neighborhoods['Neighborhood'],
                                   latitudes=NewYork_neighborhoods['Latitude'],
                                   longitudes=NewYork_neighborhoods['Longitude']
                                  )

# %%
ny_venues.head()
# Out:
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0    Wakefield              40.894705              -73.847201
# 1    Wakefield              40.894705              -73.847201
# 2    Wakefield              40.894705              -73.847201
# 3    Wakefield              40.894705              -73.847201
# 4    Wakefield              40.894705              -73.847201
#
#               Venue  Venue Latitude  Venue Longitude  Venue Category
# 0  Lollipops Gelato       40.894123       -73.845892    Dessert Shop
# 1          Rite Aid       40.896649       -73.844846        Pharmacy
# 2  Carvel Ice Cream       40.890487       -73.848568  Ice Cream Shop
# 3         Walgreens       40.896528       -73.844700        Pharmacy
# 4           Dunkin'       40.890459       -73.849089      Donut Shop

# %%
ny_venues.groupby('Neighborhood').count().head(5)
# Out:
#                Neighborhood Latitude  Neighborhood Longitude  Venue  \
# Neighborhood
# Allerton                          26                      26     26
# Annadale                          10                      10     10
# Arden Heights                      7                       7      7
# Arlington                          7                       7      7
# Arrochar                          23                      23     23
#
#                Venue Latitude  Venue Longitude  Venue Category
# Neighborhood
# Allerton                   26               26              26
# Annadale                   10               10              10
# Arden Heights               7                7               7
# Arlington                   7                7               7
# Arrochar                   23               23              23

# %%
print('There are {} neighborhoods.'.format(len(ny_venues.groupby('Neighborhood').count())))
# Out:
# There are 301 neighborhoods.

# %%
print('There are {} unique venue categories.'.format(len(ny_venues['Venue Category'].unique())))
# Out:
# There are 441 unique venue categories.

# %% [markdown]
# #### Toronto : Let's get the top 100 venues that are within a radius of 500 meters

# %%
toronto_denc_venues = getNearbyVenues(names=df_toronto_denc['Neighborhood'],
                                   latitudes=df_toronto_denc['Latitude'],
                                   longitudes=df_toronto_denc['Longitude']
                                  )

# %%
toronto_denc_venues.head()
# Out:
#                 Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Regent Park, Harbourfront               43.65426              -79.360636
# 1  Regent Park, Harbourfront               43.65426              -79.360636
# 2  Regent Park, Harbourfront               43.65426              -79.360636
# 3  Regent Park, Harbourfront               43.65426              -79.360636
# 4  Regent Park, Harbourfront               43.65426              -79.360636
#
#                     Venue  Venue Latitude  Venue Longitude  \
# 0        Roselle Desserts       43.653447       -79.362017
# 1           Tandem Coffee       43.653559       -79.361809
# 2  Cooper Koo Family YMCA       43.653249       -79.358008
# 3          Impact Kitchen       43.656369       -79.356980
# 4     Body Blitz Spa East       43.654735       -79.359874
#
#         Venue Category
# 0               Bakery
# 1          Coffee Shop
# 2  Distribution Center
# 3           Restaurant
# 4                  Spa

# %% [markdown]
# Checking how many venues were returned for each neighborhood.

# %%
toronto_denc_venues.groupby('Neighborhood').count().head(5)
# Out:
#                                                     Neighborhood Latitude  \
# Neighborhood
# Berczy Park                                                            56
# Brockton, Parkdale Village, Exhibition Place                           23
# CN Tower, King and Spadina, Railway Lands, Harb...                     16
# Central Bay Street                                                     66
# Christie                                                               16
#
#                                                     Neighborhood Longitude  \
# Neighborhood
# Berczy Park                                                             56
# Brockton, Parkdale Village, Exhibition Place                            23
# CN Tower, King and Spadina, Railway Lands, Harb...                      16
# Central Bay Street                                                      66
# Christie                                                                16
#
# ...

# %%
print('There are {} neighborhoods.'.format(len(toronto_denc_venues.groupby('Neighborhood').count())))
# Out:
# There are 39 neighborhoods.

# %% [markdown]
# Finding out how many unique categories can be curated from all the returned venues

# %%
print('There are {} uniques categories.'.format(len(toronto_denc_venues['Venue Category'].unique())))
# Out:
# There are 236 uniques categories.

# %% [markdown]
# ##### New York : Check the 10 most common venues in each neighborhood.

# %%
neighborhoods_venues_sorted.head()
# Out:
#     Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0       Allerton         Deli / Bodega           Pizza Place
# 1       Annadale           Pizza Place             Juice Bar
# 2  Arden Heights            Playground         Deli / Bodega
# 3      Arlington         Deli / Bodega   American Restaurant
# 4       Arrochar              Bus Stop    Italian Restaurant
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0    Chinese Restaurant        Discount Store                   Spa
# 1         Train Station            Restaurant              Pharmacy
# 2              Pharmacy           Coffee Shop              Bus Stop
# 3              Bus Stop         Boat or Ferry           Yoga Studio
# 4         Deli / Bodega           Pizza Place                 Hotel
#
#        6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0                Supermarket            Donut Shop         Grocery Store
# ...

# %% [markdown]
# ##### Toronto : Check the 10 most common venues in each neighborhood.

# %%
neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                                        Berczy Park                Bakery
# 1       Brockton, Parkdale Village, Exhibition Place                  Café
# 2  CN Tower, King and Spadina, Railway Lands, Har...       Airport Service
# 3                                 Central Bay Street           Coffee Shop
# 4                                           Christie         Grocery Store
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0           Coffee Shop    Seafood Restaurant          Cocktail Bar
# 1           Coffee Shop                Bakery        Breakfast Spot
# 2      Airport Terminal        Airport Lounge         Boat or Ferry
# 3        Sandwich Place    Italian Restaurant                  Café
# 4                  Café                  Park           Candy Store
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# ...

# %% [markdown]
# ### New York : Cluster Neighborhoods

# %% [markdown]
# Run k-means to cluster the neighborhood into 5 clusters.

# %%
# set number of clusters
kclusters = 5

new_york_grouped_clustering = new_york_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(new_york_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([1, 1, 3, 3, 3, 0, 0, 0, 0, 0], dtype=int32)

# %% [markdown]
# Let's create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

new_york_merged = NewYork_neighborhoods

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
new_york_merged = new_york_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

new_york_merged.head() # check the last columns!
# Out:
#   Borough Neighborhood   Latitude  Longitude  Cluster Labels  \
# 0   Bronx    Wakefield  40.894705 -73.847201             1.0
# 1   Bronx   Co-op City  40.874294 -73.829939             1.0
# 2   Bronx  Eastchester  40.887556 -73.827806             1.0
# 3   Bronx    Fieldston  40.895437 -73.905643             0.0
# 4   Bronx    Riverdale  40.890834 -73.912585             4.0
#
#   1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0              Pharmacy                  Food            Donut Shop
# 1           Bus Station  Fast Food Restaurant   Fried Chicken Joint
# 2           Bus Station  Caribbean Restaurant         Deli / Bodega
# 3           Music Venue           Bus Station                 River
# 4           Bus Station                  Park                  Bank
#
#   4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 0  Caribbean Restaurant            Laundromat        Ice Cream Shop
# ...

# %% [markdown]
# Finally, let's visualize the resulting clusters

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=10)
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %% [markdown]
# ### Toronto : Cluster Neighborhoods

# %% [markdown]
# Run k-means to cluster the neighborhood into 5 clusters.

# %%
# set number of clusters
kclusters = 5

toronto_denc_grouped_clustering = toronto_denc_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_denc_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([4, 4, 4, 4, 4, 4, 4, 4, 4, 4], dtype=int32)

# %% [markdown]
# Let's create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_denc_merged = df_toronto_denc

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_denc_merged = toronto_denc_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

toronto_denc_merged.head() # check the last columns!
# Out:
#   Postal Code           Borough               Neighborhood   Latitude  \
# 0         M5A  Downtown Toronto  Regent Park, Harbourfront  43.654260
# 1         M5B  Downtown Toronto   Garden District, Ryerson  43.657162
# 2         M5C  Downtown Toronto             St. James Town  43.651494
# 3         M4E      East Toronto                The Beaches  43.676357
# 4         M5E  Downtown Toronto                Berczy Park  43.644771
#
#    Longitude  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0 -79.360636               4           Coffee Shop                   Pub
# 1 -79.378937               4           Coffee Shop        Clothing Store
# 2 -79.375418               4           Coffee Shop                  Café
# 3 -79.293031               0     Health Food Store                 Trail
# 4 -79.373306               4                Bakery           Coffee Shop
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# ...

# %% [markdown]
# Finally, let's visualize the resulting clusters

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=10)
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %% [markdown]
# ### New York : Examine Clusters

# %% [markdown]
# **Cluster 1**

# %%
new_york_merged.loc[new_york_merged['Cluster Labels'] == 0, new_york_merged.columns[[1] + list(range(5, new_york_merged.shape[1]))]]
# Out:
#             Neighborhood       1st Most Common Venue  \
# 3              Fieldston                 Music Venue
# 9         Williamsbridge                   Nightclub
# 12           City Island      Thrift / Vintage Store
# 22           Port Morris      Furniture / Home Store
# 28           Throgs Neck                         Bar
# 29          Country Club              Sandwich Place
# 34               Belmont          Italian Restaurant
# 37            Pelham Bay        Fast Food Restaurant
# 39        Edgewater Park          Italian Restaurant
# 46             Bay Ridge                 Pizza Place
# 49            Greenpoint                 Coffee Shop
# 50             Gravesend                      Bakery
# 51        Brighton Beach          Russian Restaurant
# 52        Sheepshead Bay                Dessert Shop
# 58       Windsor Terrace               Deli / Bodega
# 59      Prospect Heights                         Bar
# 61          Williamsburg                 Pizza Place
# ...

# %% [markdown]
# **Cluster 2**

# %%
new_york_merged.loc[new_york_merged['Cluster Labels'] == 1, new_york_merged.columns[[1] + list(range(5, new_york_merged.shape[1]))]]
# Out:
#                   Neighborhood            1st Most Common Venue  \
# 0                    Wakefield                         Pharmacy
# 1                   Co-op City                      Bus Station
# 2                  Eastchester                      Bus Station
# 5                  Kingsbridge                      Pizza Place
# 6                  Marble Hill                              Gym
# 7                     Woodlawn                              Pub
# 8                      Norwood                      Pizza Place
# 10                  Baychester                       Donut Shop
# 11              Pelham Parkway               Italian Restaurant
# 13                Bedford Park                            Diner
# 14          University Heights              Fried Chicken Joint
# 15              Morris Heights                         Pharmacy
# 16                     Fordham             Fast Food Restaurant
# 17                East Tremont                      Pizza Place
# ...

# %% [markdown]
# **Cluster 3**

# %%
new_york_merged.loc[new_york_merged['Cluster Labels'] == 2, new_york_merged.columns[[1] + list(range(5, new_york_merged.shape[1]))]]
# Out:
#     Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 193   Brookville         Deli / Bodega           Yoga Studio
# 202  Grymes Hill               Dog Run         Deli / Bodega
#
#     3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 193         Fishing Store               Exhibit            Eye Doctor
# 202           Flea Market            Eye Doctor               Factory
#
#     6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 193               Factory    Falafel Restaurant                  Farm
# 202    Falafel Restaurant                  Farm        Farmers Market
#
#     9th Most Common Venue 10th Most Common Venue
# 193        Farmers Market   Fast Food Restaurant
# 202  Fast Food Restaurant                  Field

# %% [markdown]
# **Cluster 4**

# %%
new_york_merged.loc[new_york_merged['Cluster Labels'] == 3, new_york_merged.columns[[1] + list(range(5, new_york_merged.shape[1]))]]
# Out:
#          Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 77    Manhattan Beach                  Café              Bus Stop
# 198      New Brighton              Bus Stop         Deli / Bodega
# 205     Port Richmond   Rental Car Location      Basketball Court
# 206  Mariner's Harbor              Bus Stop         Deli / Bodega
# 217       Tottenville    Italian Restaurant        Cosmetics Shop
# 224         Park Hill              Bus Stop           Coffee Shop
# 226      Graniteville         Grocery Store              Bus Stop
# 227         Arlington         Deli / Bodega   American Restaurant
# 228          Arrochar              Bus Stop    Italian Restaurant
# 229          Grasmere              Bus Stop         Grocery Store
# 238      Butler Manor        Baseball Field                  Pool
# 241     Arden Heights            Playground         Deli / Bodega
# 245        Bloomfield     Recreation Center          Burger Joint
# ...

# %% [markdown]
# **Cluster 5**

# %%
new_york_merged.loc[new_york_merged['Cluster Labels'] == 4, new_york_merged.columns[[1] + list(range(5, new_york_merged.shape[1]))]]
# Out:
#          Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 4           Riverdale           Bus Station                  Park
# 27       Clason Point                  Park         Boat or Ferry
# 35     Spuyten Duyvil                  Park                  Bank
# 148  South Ozone Park                  Park                   Bar
# 188         Laurelton  Caribbean Restaurant        Cosmetics Shop
# 192        Somerville       Nature Preserve             Surf Spot
# 203         Todt Hill                  Park           Yoga Studio
#
#     3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 4                    Bank                   Gym            Food Truck
# 27           Home Service            Playground        Scenic Lookout
# 35        Thai Restaurant              Pharmacy        Scenic Lookout
# 148            Food Truck            Donut Shop        Sandwich Place
# 188         Train Station                  Park            Playground
# ...

# %% [markdown]
# Clusters 1,2 and 4 have more number of neighbourhoods whereas clusters 3 and 5 have fewer number of neighbourhoods.
# Clusters 1,2 and 4 are good for people who are looking for more amenities the neighbourhoods is going to offer them.
# Clusters 3 and 5 are good for people who want to do business if they find fewer number of venues in the neighbourhoods.

# %% [markdown]
# ### Toronto : Examine Clusters

# %% [markdown]
# **Cluster 1**

# %%
toronto_denc_merged.loc[toronto_denc_merged['Cluster Labels'] == 0, toronto_denc_merged.columns[[1] + list(range(5, toronto_denc_merged.shape[1]))]]
# Out:
#         Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 3  East Toronto               0     Health Food Store                 Trail
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 3                   Pub             Wine Shop      Doner Restaurant
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 3                 Diner        Discount Store   Distribution Center
#
#   9th Most Common Venue 10th Most Common Venue
# 3               Dog Run    Dumpling Restaurant

# %% [markdown]
# **Cluster 2**

# %%
toronto_denc_merged.loc[toronto_denc_merged['Cluster Labels'] == 1, toronto_denc_merged.columns[[1] + list(range(5, toronto_denc_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 21   Central Toronto               1                  Park
# 29   Central Toronto               1                   Gym
# 33  Downtown Toronto               1                  Park
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 21         Jewelry Store                 Trail      Sushi Restaurant
# 29                 Trail                  Park          Gourmet Shop
# 33            Playground                 Trail      Department Store
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 21             Wine Shop          Dessert Shop           Escape Room
# 29           Event Space           Escape Room     Electronics Store
# 33  Ethiopian Restaurant           Escape Room     Electronics Store
#
#           8th Most Common Venue        9th Most Common Venue  \
# 21            Electronics Store  Eastern European Restaurant
# ...

# %% [markdown]
# **Cluster 3**

# %%
toronto_denc_merged.loc[toronto_denc_merged['Cluster Labels'] == 2, toronto_denc_merged.columns[[1] + list(range(5, toronto_denc_merged.shape[1]))]]
# Out:
#             Borough  Cluster Labels 1st Most Common Venue  \
# 19  Central Toronto               2  Fast Food Restaurant
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 19          Home Service                Garden      Department Store
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 19  Ethiopian Restaurant           Escape Room     Electronics Store
#
#           8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 19  Eastern European Restaurant   Dumpling Restaurant             Donut Shop

# %% [markdown]
# **Cluster 4**

# %%
toronto_denc_merged.loc[toronto_denc_merged['Cluster Labels'] == 3, toronto_denc_merged.columns[[1] + list(range(5, toronto_denc_merged.shape[1]))]]
# Out:
#                   Borough  Cluster Labels 1st Most Common Venue  \
# 9  East York/East Toronto               3          Intersection
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 9                  Park     Convenience Store             Wine Shop
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 9          Dessert Shop  Ethiopian Restaurant           Escape Room
#
#   8th Most Common Venue        9th Most Common Venue 10th Most Common Venue
# 9     Electronics Store  Eastern European Restaurant    Dumpling Restaurant

# %% [markdown]
# **Cluster 5**

# %%
toronto_denc_merged.loc[toronto_denc_merged['Cluster Labels'] == 4, toronto_denc_merged.columns[[1] + list(range(5, toronto_denc_merged.shape[1]))]]
# Out:
#                    Borough  Cluster Labels 1st Most Common Venue  \
# 0         Downtown Toronto               4           Coffee Shop
# 1         Downtown Toronto               4           Coffee Shop
# 2         Downtown Toronto               4           Coffee Shop
# 4         Downtown Toronto               4                Bakery
# 5         Downtown Toronto               4           Coffee Shop
# 6         Downtown Toronto               4         Grocery Store
# 7         Downtown Toronto               4           Coffee Shop
# 8             West Toronto               4                Bakery
# 10        Downtown Toronto               4           Coffee Shop
# 11            West Toronto               4                   Bar
# 12            East Toronto               4      Greek Restaurant
# 13        Downtown Toronto               4           Coffee Shop
# 14            West Toronto               4                  Café
# ...

# %% [markdown]
# Only Cluster 5 has more number of neighbourhoods whereas clusters 1,2,3 and 4 have fewer number of neighbourhoods.
# Cluster 5 is good for people who are looking for more amenities the neighbourhoods is going to offer them.
# Clusters 1,2,3 and 4 are good for people who want to do business if they find fewer number of venues in the neighbourhoods.

# %% [markdown]
# ## Results and Discussion

# %% [markdown]
# In this section we are going to address the following queries.
#
# Identifying the top five and common venue categories across both New York City and Toronto.
# Identifying the top five neighborhoods with most and least number of venues in its neighborhood for both the cities.
# Identifying the top five and common restaurants that is most sought after in New York City and Toronto.
# Identifying the top five neighbourhoods with most and least number of restaurants in its neighbourhood across both the cities.

# %% [markdown]
# ###  Identifying the top five Venue Categories in New York City.

# %%
ny_venues.groupby('Venue Category').count().sort_values('Venue', ascending=False).head(5)
# Out:
#                     Neighborhood  Neighborhood Latitude  \
# Venue Category
# Pizza Place                  430                    430
# Italian Restaurant           311                    311
# Coffee Shop                  305                    305
# Deli / Bodega                269                    269
# Chinese Restaurant           229                    229
#
#                     Neighborhood Longitude  Venue  Venue Latitude  \
# Venue Category
# Pizza Place                            430    430             430
# Italian Restaurant                     311    311             311
# Coffee Shop                            305    305             305
# Deli / Bodega                          269    269             269
# Chinese Restaurant                     229    229             229
#
#                     Venue Longitude
# Venue Category
# Pizza Place                     430
# Italian Restaurant              311
# Coffee Shop                     305
# ...

# %% [markdown]
# The top five "Venue Category" in New York are Pizza Place, Italian Restaurant, Coffee Shop, Deli / Bodega and Chinese Restaurant

# %% [markdown]
# ### Identifying the top five Venue Categories in Toronto.

# %%
toronto_denc_venues.groupby('Venue Category').count().sort_values('Venue', ascending=False).head(5)
# Out:
#                     Neighborhood  Neighborhood Latitude  \
# Venue Category
# Coffee Shop                  142                    142
# Café                          83                     83
# Restaurant                    52                     52
# Bakery                        38                     38
# Italian Restaurant            37                     37
#
#                     Neighborhood Longitude  Venue  Venue Latitude  \
# Venue Category
# Coffee Shop                            142    142             142
# Café                                    83     83              83
# Restaurant                              52     52              52
# Bakery                                  38     38              38
# Italian Restaurant                      37     37              37
#
#                     Venue Longitude
# Venue Category
# Coffee Shop                     142
# Café                             83
# Restaurant                       52
# ...

# %% [markdown]
# The top five "Venue Category" in Toronto are Coffee Shop, Café, Restaurant, Bakery and Italian Restaurant.

# %% [markdown]
# ###  Identifying the top common Venue Categories across both New York City and Toronto.

# %% [markdown]
# Italian Restaurant, Coffee Shop are top common 'Venue Category' across both "New York" and "Toronto",
# New York city is also famous for Pizza Place, Deli / Bodega and Chinese Restaurant, while
# Toronto is also famous for Café, Restaurant and Bakery.

# %% [markdown]
# ###  Identifying the top five Neighborhoods with most number of venues in its Neighborhood.

# %% [markdown]
# **The top five Neighborhoods with most number of venues in "New York"**

# %%
ny_venues.groupby('Neighborhood').count().sort_values('Venue Category', ascending=False).head(5)
# Out:
#               Neighborhood Latitude  Neighborhood Longitude  Venue  \
# Neighborhood
# Murray Hill                     147                     147    147
# Chelsea                         104                     104    104
# Lenox Hill                      100                     100    100
# Little Italy                    100                     100    100
# Chinatown                       100                     100    100
#
#               Venue Latitude  Venue Longitude  Venue Category
# Neighborhood
# Murray Hill              147              147             147
# Chelsea                  104              104             104
# Lenox Hill               100              100             100
# Little Italy             100              100             100
# Chinatown                100              100             100

# %% [markdown]
# ###  Identifying the top five Neighborhoods with most number of venues in its Neighborhood.

# %% [markdown]
# **The top five Neighborhoods with most number of venues in "Toronto"**

# %%
toronto_denc_venues.groupby('Neighborhood').count().sort_values('Venue', ascending=False).head(5)
# Out:
#                                                    Neighborhood Latitude  \
# Neighborhood
# Toronto Dominion Centre, Design Exchange                             100
# Richmond, Adelaide, King                                             100
# Commerce Court, Victoria Hotel                                       100
# Harbourfront East, Union Station, Toronto Islands                    100
# Garden District, Ryerson                                             100
#
#                                                    Neighborhood Longitude  \
# Neighborhood
# Toronto Dominion Centre, Design Exchange                              100
# Richmond, Adelaide, King                                              100
# Commerce Court, Victoria Hotel                                        100
# Harbourfront East, Union Station, Toronto Islands                     100
# Garden District, Ryerson                                              100
#
# ...

# %% [markdown]
# ###  Identifying the bottom five Neighborhoods with least number of venues in its Neighborhood.

# %% [markdown]
# The bottom five Neighborhoods with least number of venues in "New York".
# This Neighborhoods can be sought to do business.

# %%
ny_venues.groupby('Neighborhood').count().sort_values('Venue Category').head(5)
# Out:
#               Neighborhood Latitude  Neighborhood Longitude  Venue  \
# Neighborhood
# Brookville                        1                       1      1
# Mill Island                       1                       1      1
# Todt Hill                         1                       1      1
# Grymes Hill                       2                       2      2
# Graniteville                      2                       2      2
#
#               Venue Latitude  Venue Longitude  Venue Category
# Neighborhood
# Brookville                 1                1               1
# Mill Island                1                1               1
# Todt Hill                  1                1               1
# Grymes Hill                2                2               2
# Graniteville               2                2               2

# %% [markdown]
# ###  Identifying the bottom five Neighborhoods with least number of venues in its Neighborhood.

# %% [markdown]
# The bottom five Neighborhoods with least number of venues in "Toronto".
# This Neighborhoods can be sought to do business.

# %%
toronto_denc_venues.groupby('Neighborhood').count().sort_values('Venue').head(5)
# Out:
#                              Neighborhood Latitude  Neighborhood Longitude  \
# Neighborhood
# Moore Park, Summerhill East                      3                       3
# Roselawn                                         3                       3
# Forest Hill North & West                         4                       4
# Rosedale                                         4                       4
# The Beaches                                      4                       4
#
#                              Venue  Venue Latitude  Venue Longitude  \
# Neighborhood
# Moore Park, Summerhill East      3               3                3
# Roselawn                         3               3                3
# Forest Hill North & West         4               4                4
# Rosedale                         4               4                4
# The Beaches                      4               4                4
#
#                              Venue Category
# Neighborhood
# ...

# %% [markdown]
# ###  Identifying the "Restaurants" in New York City.

# %%
ny_venues_restaurant = ny_venues[ny_venues['Venue Category'].str.contains("Restaurant")].reset_index(drop=True)
ny_venues_restaurant.head()
# Out:
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0    Wakefield              40.894705              -73.847201
# 1   Co-op City              40.874294              -73.829939
# 2   Co-op City              40.874294              -73.829939
# 3   Co-op City              40.874294              -73.829939
# 4  Eastchester              40.887556              -73.827806
#
#                                  Venue  Venue Latitude  Venue Longitude  \
# 0  Cooler Runnings Jamaican Restaurant       40.898083       -73.850259
# 1                               Arby's       40.870411       -73.828606
# 2                 Townhouse Restaurant       40.876086       -73.828868
# 3                            Kennedy's       40.876807       -73.829627
# 4                          Fish & Ting       40.885656       -73.829197
#
#          Venue Category
# 0  Caribbean Restaurant
# 1  Fast Food Restaurant
# 2            Restaurant
# 3  Fast Food Restaurant
# 4  Caribbean Restaurant

# %% [markdown]
# ###  Identifying the top five "Restaurants" that is most sought after in New York City.

# %%
ny_venues_restaurant.groupby('Venue Category').count().sort_values('Venue', ascending=False).head(5)
# Out:
#                      Neighborhood  Neighborhood Latitude  \
# Venue Category
# Italian Restaurant            311                    311
# Chinese Restaurant            229                    229
# Mexican Restaurant            175                    175
# American Restaurant           160                    160
# Sushi Restaurant              108                    108
#
#                      Neighborhood Longitude  Venue  Venue Latitude  \
# Venue Category
# Italian Restaurant                      311    311             311
# Chinese Restaurant                      229    229             229
# Mexican Restaurant                      175    175             175
# American Restaurant                     160    160             160
# Sushi Restaurant                        108    108             108
#
#                      Venue Longitude
# Venue Category
# Italian Restaurant               311
# Chinese Restaurant               229
# Mexican Restaurant               175
# ...

# %% [markdown]
# ###  Identifying the "Restaurants" in Toronto.

# %%
df_toronto_restaurant = toronto_denc_venues[toronto_denc_venues['Venue Category'].str.contains("Restaurant")].reset_index(drop=True)
df_toronto_restaurant.head()
# Out:
#                 Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Regent Park, Harbourfront              43.654260              -79.360636
# 1  Regent Park, Harbourfront              43.654260              -79.360636
# 2  Regent Park, Harbourfront              43.654260              -79.360636
# 3   Garden District, Ryerson              43.657162              -79.378937
# 4   Garden District, Ryerson              43.657162              -79.378937
#
#                              Venue  Venue Latitude  Venue Longitude  \
# 0                   Impact Kitchen       43.656369       -79.356980
# 1                        El Catrin       43.650601       -79.358920
# 2       Cluny Bistro & Boulangerie       43.650565       -79.357843
# 3  Hokkaido Ramen Santouka らーめん山頭火       43.656435       -79.377586
# 4           Chipotle Mexican Grill       43.656860       -79.380910
#
#        Venue Category
# 0          Restaurant
# 1  Mexican Restaurant
# 2   French Restaurant
# ...

# %% [markdown]
# ###  Identifying the top five "Restaurants" that is most sought after in Toronto.

# %%
df_toronto_restaurant.groupby('Venue Category').count().sort_values('Venue', ascending=False).head(5)
# Out:
#                      Neighborhood  Neighborhood Latitude  \
# Venue Category
# Restaurant                     52                     52
# Italian Restaurant             37                     37
# Japanese Restaurant            33                     33
# Sushi Restaurant               23                     23
# Seafood Restaurant             22                     22
#
#                      Neighborhood Longitude  Venue  Venue Latitude  \
# Venue Category
# Restaurant                               52     52              52
# Italian Restaurant                       37     37              37
# Japanese Restaurant                      33     33              33
# Sushi Restaurant                         23     23              23
# Seafood Restaurant                       22     22              22
#
#                      Venue Longitude
# Venue Category
# Restaurant                        52
# Italian Restaurant                37
# Japanese Restaurant               33
# ...

# %% [markdown]
# ###  Identifying the top common "Restaurants" that is most sought after across both New York City and Toronto.

# %% [markdown]
# While **Italian Restaurant** and **Sushi Restaurant** are common in both the cities that is most sought after,
# **New York** is also famous for **Chinese Restaurant, Mexican Restaurant, American Restaurant.**  and
# **Toronto** is also famous for **Japanese Restaurant** and **Seafood Restaurant.**

# %% [markdown]
# ###  Identifying the neighbourhoods with most number of "Restaurants" in its neighbourhood in New York City.

# %%
ny_venues_restaurant.groupby('Neighborhood').count().sort_values('Venue', ascending=False).head(5)
# Out:
#                    Neighborhood Latitude  Neighborhood Longitude  Venue  \
# Neighborhood
# Murray Hill                           55                      55     55
# Greenwich Village                     43                      43     43
# East Village                          38                      38     38
# Chinatown                             38                      38     38
# Upper West Side                       37                      37     37
#
#                    Venue Latitude  Venue Longitude  Venue Category
# Neighborhood
# Murray Hill                    55               55              55
# Greenwich Village              43               43              43
# East Village                   38               38              38
# Chinatown                      38               38              38
# Upper West Side                37               37              37

# %% [markdown]
# ###  Identifying the neighbourhoods with most number of "Restaurants" in its neighbourhood in Toronto.

# %%
df_toronto_restaurant.groupby('Neighborhood').count().sort_values('Venue', ascending=False).head(5)
# Out:
#                                           Neighborhood Latitude  \
# Neighborhood
# First Canadian Place, Underground city                       29
# Commerce Court, Victoria Hotel                               27
# Toronto Dominion Centre, Design Exchange                     26
# Church and Wellesley                                         25
# Richmond, Adelaide, King                                     25
#
#                                           Neighborhood Longitude  Venue  \
# Neighborhood
# First Canadian Place, Underground city                        29     29
# Commerce Court, Victoria Hotel                                27     27
# Toronto Dominion Centre, Design Exchange                      26     26
# Church and Wellesley                                          25     25
# Richmond, Adelaide, King                                      25     25
#
#                                           Venue Latitude  Venue Longitude  \
# Neighborhood
# ...

# %% [markdown]
# ###  Identifying the neighbourhoods with least number of "Restaurants" in its neighbourhood in New York City.

# %%
ny_venues_restaurant_least = ny_venues_restaurant.groupby('Neighborhood').count().sort_values('Venue').head(5)
ny_venues_restaurant_least
# Out:
#                  Neighborhood Latitude  Neighborhood Longitude  Venue  \
# Neighborhood
# Lighthouse Hill                      1                       1      1
# Sea Gate                             1                       1      1
# Roxbury                              1                       1      1
# Richmond Town                        1                       1      1
# Queensbridge                         1                       1      1
#
#                  Venue Latitude  Venue Longitude  Venue Category
# Neighborhood
# Lighthouse Hill               1                1               1
# Sea Gate                      1                1               1
# Roxbury                       1                1               1
# Richmond Town                 1                1               1
# Queensbridge                  1                1               1

# %%
#print(ny_venues_restaurant[ny_venues_restaurant['Neighborhood'] == 'Lighthouse Hill'])       # Italian Restaurant
#print(ny_venues_restaurant[ny_venues_restaurant['Neighborhood'] == 'Sea Gate'])              # American Restaurant
#print(ny_venues_restaurant[ny_venues_restaurant['Neighborhood'] == 'Roxbury'])               # Fast Food Restaurant
#print(ny_venues_restaurant[ny_venues_restaurant['Neighborhood'] == 'Richmond Town'])         # Italian Restaurant
#print(ny_venues_restaurant[ny_venues_restaurant['Neighborhood'] == 'Queensbridge'])          # Spanish Restaurant

# %% [markdown]
# The neighborhoods 'Lighthouse Hill' and 'Richmond Town' even though contains Italian restaurant that is most sought after in New York,
# can be considered for setting up either Chinese, Mexican, American, Sushi restaurants.
#
# The neighborhood 'Sea Gate' even though contains American restaurant that is also most sought after in New York,
# can be considered for setting up either Italian, Chinese, Mexican, Sushi restaurants.
#
# The neighborhoods 'Roxbury' and 'Queensbridge' although has one restaurant each, doesn't contain restaurants that is most sought after in New York.
# This neighborhoods can be considered for setting up either Italian, Chinese, Mexican, American, Sushi restaurants.

# %% [markdown]
# ### Identifying the neighbourhoods with least number of "Restaurants" in its neighbourhood in Toronto.

# %%
df_toronto_restaurant.groupby('Neighborhood').count().sort_values('Venue').head(5)
# Out:
#                                               Neighborhood Latitude  \
# Neighborhood
# Roselawn                                                          1
# Dufferin, Dovercourt Village                                      1
# Forest Hill North & West                                          1
# Brockton, Parkdale Village, Exhibition Place                      2
# The Annex, North Midtown, Yorkville                               2
#
#                                               Neighborhood Longitude  Venue  \
# Neighborhood
# Roselawn                                                           1      1
# Dufferin, Dovercourt Village                                       1      1
# Forest Hill North & West                                           1      1
# Brockton, Parkdale Village, Exhibition Place                       2      2
# The Annex, North Midtown, Yorkville                                2      2
#
# ...

# %%
#print(df_toronto_restaurant[df_toronto_restaurant['Neighborhood'] == 'Roselawn'])                                       # Fast Food Restaurant 
#print(df_toronto_restaurant[df_toronto_restaurant['Neighborhood'] == 'Dufferin, Dovercourt Village'])                   # Middle Eastern Restaurant
#print(df_toronto_restaurant[df_toronto_restaurant['Neighborhood'] == 'Forest Hill North & West'])                       # Sushi Restaurant
#print(df_toronto_restaurant[df_toronto_restaurant['Neighborhood'] == 'Brockton, Parkdale Village, Exhibition Place'])   # Italian Restaurant / Restaurant
#print(df_toronto_restaurant[df_toronto_restaurant['Neighborhood'] == 'The Annex, North Midtown, Yorkville'])            # Indian Restaurant / Middle Eastern Restaurant

# %% [markdown]
# The neighbourhoods 'Roselawn' and 'Dufferin, Dovercourt Village' has one restaurant each and can be considered for setting up
# either Italian, Japanese, Sushi and Seafood restaurant and also for the neighbourhood 'The Annex, North Midtown, Yorkville'
# which has Indian / Middle Eastern Restaurant
#
# The neighbourhood 'Forest Hill North & West' has one Sushi Restaurant and can be considered for setting up Italian, Japanese and Seafood restaurant.
#
# The neighbourhood 'Brockton, Parkdale Village, Exhibition Place' has Italian Restaurant and can be considered for setting up either Japanese, Sushi and Seafood restaurant.

# %% [markdown]
# ## Discussion

# %% [markdown]
# There are lots of venues available in both New-York city and Toronto. While Italian Restaurant, Coffee Shop are top common Venue Categories across both the cities, New York city is also famous for Pizza Place, Deli / Bodega and Chinese Restaurant, while Toronto is also famous for Café, Restaurants and Bakery.
#
# New-York city has Murray Hill, Chelsea, Lenox Hill, Little Italy and Chinatown neighborhoods with most number of venues while Toronto has Toronto Dominion Centre, Richmond, Adelaide, Commerce Court, Harbourfront East, Union Station, Toronto Islands, Garden District, Ryerson etc with most number of venues.
#
# The neighborhoods Brookville, Mill Island, Todt Hill, Grymes Hill and Graniteville of New-York city have fewer number of venues, while Toronto has Moore Park, Summerhill East, Roselawn,  Forest Hill North & West, Rosedale and The Beaches neighborhoods with fewer number of venues.This neighborhoods of both the cities can be sought after to do business.
#
# The neighbourhoods of New-York city and Toronto are very mulitcultural. There are lots of different cusines available in both the cities.While Italian and Sushi Restaurants are common in both the cities, New York is also famous for Chinese, Mexican, American  Restaurants  and Toronto is also famous for Japanese and Seafood Restaurants.
#
# The neighbourhoods of New-York city, Murray Hill, Greenwich Village, Chinatown, East Village and Upper West Side have more number of restaurants,  while Toronto has the following neighbourhoods, First Canadian Place, Toronto Dominion Centre, Commerce Court, Church and Wellesley and Richmond with more number of restaurants.
#
# The neighborhoods 'Lighthouse Hill' and 'Richmond Town' even though contains Italian restaurant that is most sought after in New York, can be considered for setting up either Chinese, Mexican, American, Sushi restaurants.The neighborhood 'Sea Gate' even though contains American restaurant that is also most sought after in New York, can be considered for setting up either Italian, Chinese, Mexican, Sushi restaurants.The neighborhoods 'Roxbury' and 'Queensbridge' although has one restaurant each, doesn't contain restaurants that is most sought after in New York.This neighborhoods can be considered for setting up either Italian, Chinese, Mexican, American, Sushi restaurants.
#
# The neighbourhoods 'Roselawn' and 'Dufferin, Dovercourt Village' has one restaurant each and can be considered for setting up either Italian, Japanese, Sushi and Seafood restaurant and also for the neighbourhood 'The Annex, North Midtown, Yorkville' which has Indian / Middle Eastern Restaurant.The neighbourhood 'Forest Hill North & West' has one Sushi Restaurant and can be considered for setting up Italian, Japanese and Seafood restaurant.The neighbourhood 'Brockton, Parkdale Village, Exhibition Place' has Italian Restaurant and can be considered for setting up either Japanese, Sushi and Seafood restaurant.
#
# Further analysis could be carried out based on the community in the region.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# The purpose of this project was to explore the neighbourhoods of New-York city and Toronto and see how neighbourhoods offer better amenities to potential tourists and migrants. We explored both the cities based on their latitude and longitude information  and then extrapolated the venues present in each of the neighbourhoods and clustering nearby neighbourhoods together.
#
# We could see that each of the neighbourhoods in both the cities have a wide variety of experiences to offer which is unique in it's own way. The cultural diversity is quite evident which also gives the feeling of a sense of inclusion.
#
# Both New-York city and Toronto seem to offer better amenities with lots of places to explore, beautiful landscapes, amazing food and a wide variety of culture. Overall, it's upto the stakeholders to decide which neighbourhoods/venues they would prefer more based on their interest.
#
# The detailed code is available on
# <a href= "https://github.com/vruhupk/Coursera_Capstone./blob/master/Neighborhoods%20of%20New-York%20and%20Toronto.ipynb">GitHub</a>

# %% [markdown]
# ### References

# %% [markdown]
# Wikipedia - New York City and Toronto Pages
# https://en.wikipedia.org/wiki/New_York_City
# https://en.wikipedia.org/wiki/Toronto
# Kaggle: https://www.kaggle.com
# GitHub: https://github.com
# Foursquare - Independent Location Data Platform https://foursquare.com
# List of postal codes of Canada: M https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M
